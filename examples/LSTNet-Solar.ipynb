# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.model.lstnet import LSTNetEstimator
from pts.dataset.repository.datasets import dataset_recipes
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# ## Prepeare data set

# %%
dataset = get_dataset("solar_nips", regenerate=False)

# %%
dataset.metadata
# Out:
# MetaData(freq='H', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='137')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=24)

# %%
train_grouper = MultivariateGrouper(max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)), 
                                   max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %% [markdown]
# ## Evaluator

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:],
                                  target_agg_funcs={'sum': np.sum})

# %% [markdown]
# ## `LSTNet`

# %%
estimator = LSTNetEstimator(
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
  
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*5,
    scaling="std",
    trainer_kwargs=dict(max_epochs=50, accelerator='gpu', devices='1'),
)

# %%
predictor = estimator.train(dataset_train, cache_data=True)
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:197: UserWarning: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
#   rank_zero_warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params | In sizes | Out sizes
# -------------------------------------------------------------------
# 0 | model | LSTNetModel | 170 K  | ?        | [1, 1, 24, 137]
# 1 | loss  | L1Loss      | 0      | ?        | ?
# -------------------------------------------------------------------
# 170 K     Trainable params
# 0         Non-trainable params
# 170 K     Total params
# 0.683     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 3.13834 (best 3.13834), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 2.88114 (best 2.88114), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 2.76591 (best 2.76591), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' was not in top 1
# Epoch 4, global step 250: 'train_loss' was not in top 1
# Epoch 5, global step 300: 'train_loss' was not in top 1
# Epoch 6, global step 350: 'train_loss' was not in top 1
# Epoch 7, global step 400: 'train_loss' was not in top 1
# Epoch 8, global step 450: 'train_loss' reached 0.30912 (best 0.30912), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' was not in top 1
# Epoch 10, global step 550: 'train_loss' was not in top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' was not in top 1
# Epoch 13, global step 700: 'train_loss' was not in top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' was not in top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' was not in top 1
# Epoch 18, global step 950: 'train_loss' was not in top 1
# Epoch 19, global step 1000: 'train_loss' was not in top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' was not in top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' reached 0.25891 (best 0.25891), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' was not in top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' reached 0.25828 (best 0.25828), saving model to '/home/kashif/pytorch-ts/examples/lightning_logs/version_77/checkpoints/epoch=34-step=1750.ckpt' as top 1
# Epoch 35, global step 1800: 'train_loss' was not in top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' was not in top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' was not in top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:197: UserWarning: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
#   rank_zero_warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                             predictor=predictor,
                                             num_samples=100)
forecasts = list(forecast_it)
targets = list(ts_it)
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 100.67it/s]
# Running evaluation: 7it [00:00, 104.29it/s]
# Running evaluation: 7it [00:00, 104.68it/s]
# Running evaluation: 7it [00:00, 104.13it/s]
# Running evaluation: 7it [00:00, 104.46it/s]
# Running evaluation: 7it [00:00, 103.98it/s]
# Running evaluation: 7it [00:00, 103.45it/s]
# Running evaluation: 7it [00:00, 103.60it/s]
# Running evaluation: 7it [00:00, 104.14it/s]
# Running evaluation: 7it [00:00, 103.74it/s]
# Running evaluation: 7it [00:00, 104.18it/s]
# Running evaluation: 7it [00:00, 103.26it/s]
# Running evaluation: 7it [00:00, 100.74it/s]
# Running evaluation: 7it [00:00, 102.91it/s]
# Running evaluation: 7it [00:00, 103.54it/s]
# Running evaluation: 7it [00:00, 104.27it/s]
# Running evaluation: 7it [00:00, 104.64it/s]
# Running evaluation: 7it [00:00, 104.29it/s]
# Running evaluation: 7it [00:00, 104.40it/s]
# Running evaluation: 7it [00:00, 104.15it/s]
# Running evaluation: 7it [00:00, 104.03it/s]
# Running evaluation: 7it [00:00, 100.35it/s]
# Running evaluation: 7it [00:00, 104.58it/s]
# Running evaluation: 7it [00:00, 103.97it/s]
# Running evaluation: 7it [00:00, 104.60it/s]
# Running evaluation: 7it [00:00, 104.47it/s]
# Running evaluation: 7it [00:00, 104.52it/s]
# Running evaluation: 7it [00:00, 104.90it/s]
# Running evaluation: 7it [00:00, 104.50it/s]
# Running evaluation: 7it [00:00, 23.84it/s]
# Running evaluation: 7it [00:00, 104.01it/s]
# Running evaluation: 7it [00:00, 104.42it/s]
# Running evaluation: 7it [00:00, 103.67it/s]
# Running evaluation: 7it [00:00, 102.85it/s]
# Running evaluation: 7it [00:00, 104.33it/s]
# Running evaluation: 7it [00:00, 103.79it/s]
# Running evaluation: 7it [00:00, 104.37it/s]
# Running evaluation: 7it [00:00, 104.02it/s]
# Running evaluation: 7it [00:00, 104.00it/s]
# Running evaluation: 7it [00:00, 104.20it/s]
# Running evaluation: 7it [00:00, 104.10it/s]
# Running evaluation: 7it [00:00, 103.71it/s]
# Running evaluation: 7it [00:00, 103.87it/s]
# Running evaluation: 7it [00:00, 103.81it/s]
# Running evaluation: 7it [00:00, 104.03it/s]
# Running evaluation: 7it [00:00, 103.59it/s]
# Running evaluation: 7it [00:00, 104.15it/s]
# Running evaluation: 7it [00:00, 100.16it/s]
# Running evaluation: 7it [00:00, 99.58it/s]
# Running evaluation: 7it [00:00, 104.25it/s]
# Running evaluation: 7it [00:00, 103.64it/s]
# Running evaluation: 7it [00:00, 103.90it/s]
# Running evaluation: 7it [00:00, 104.22it/s]
# Running evaluation: 7it [00:00, 104.17it/s]
# Running evaluation: 7it [00:00, 104.40it/s]
# Running evaluation: 7it [00:00, 103.89it/s]
# Running evaluation: 7it [00:00, 104.23it/s]
# Running evaluation: 7it [00:00, 103.31it/s]
# Running evaluation: 7it [00:00, 103.65it/s]
# Running evaluation: 7it [00:00, 103.71it/s]
# Running evaluation: 7it [00:00, 103.94it/s]
# Running evaluation: 7it [00:00, 103.77it/s]
# Running evaluation: 7it [00:00, 103.91it/s]
# Running evaluation: 7it [00:00, 103.84it/s]
# Running evaluation: 7it [00:00, 103.94it/s]
# Running evaluation: 7it [00:00, 103.28it/s]
# Running evaluation: 7it [00:00, 103.78it/s]
# Running evaluation: 7it [00:00, 103.48it/s]
# Running evaluation: 7it [00:00, 103.33it/s]
# Running evaluation: 7it [00:00, 103.48it/s]
# Running evaluation: 7it [00:00, 103.53it/s]
# Running evaluation: 7it [00:00, 103.00it/s]
# Running evaluation: 7it [00:00, 103.86it/s]
# Running evaluation: 7it [00:00, 103.35it/s]
# Running evaluation: 7it [00:00, 103.47it/s]
# Running evaluation: 7it [00:00, 103.54it/s]
# Running evaluation: 7it [00:00, 103.55it/s]
# Running evaluation: 7it [00:00, 103.89it/s]
# Running evaluation: 7it [00:00, 103.33it/s]
# Running evaluation: 7it [00:00, 103.21it/s]
# Running evaluation: 7it [00:00, 101.75it/s]
# Running evaluation: 7it [00:00, 103.84it/s]
# Running evaluation: 7it [00:00, 104.29it/s]
# Running evaluation: 7it [00:00, 101.50it/s]
# Running evaluation: 7it [00:00, 101.67it/s]
# Running evaluation: 7it [00:00, 104.08it/s]
# Running evaluation: 7it [00:00, 104.33it/s]
# Running evaluation: 7it [00:00, 104.63it/s]
# Running evaluation: 7it [00:00, 104.34it/s]
# Running evaluation: 7it [00:00, 103.24it/s]
# Running evaluation: 7it [00:00, 102.90it/s]
# Running evaluation: 7it [00:00, 103.95it/s]
# Running evaluation: 7it [00:00, 103.64it/s]
# Running evaluation: 7it [00:00, 103.79it/s]
# Running evaluation: 7it [00:00, 103.74it/s]
# Running evaluation: 7it [00:00, 103.26it/s]
# Running evaluation: 7it [00:00, 104.09it/s]
# Running evaluation: 7it [00:00, 103.92it/s]
# Running evaluation: 7it [00:00, 103.72it/s]
# Running evaluation: 7it [00:00, 104.20it/s]
# Running evaluation: 7it [00:00, 104.20it/s]
# Running evaluation: 7it [00:00, 103.89it/s]
# Running evaluation: 7it [00:00, 104.02it/s]
# Running evaluation: 7it [00:00, 103.79it/s]
# Running evaluation: 7it [00:00, 103.69it/s]
# Running evaluation: 7it [00:00, 103.75it/s]
# Running evaluation: 7it [00:00, 103.38it/s]
# Running evaluation: 7it [00:00, 103.58it/s]
# Running evaluation: 7it [00:00, 104.18it/s]
# Running evaluation: 7it [00:00, 104.01it/s]
# Running evaluation: 7it [00:00, 103.91it/s]
# Running evaluation: 7it [00:00, 103.83it/s]
# Running evaluation: 7it [00:00, 104.16it/s]
# Running evaluation: 7it [00:00, 104.27it/s]
# Running evaluation: 7it [00:00, 103.44it/s]
# Running evaluation: 7it [00:00, 104.46it/s]
# Running evaluation: 7it [00:00, 103.38it/s]
# Running evaluation: 7it [00:00, 103.96it/s]
# Running evaluation: 7it [00:00, 104.09it/s]
# Running evaluation: 7it [00:00, 102.77it/s]
# Running evaluation: 7it [00:00, 103.49it/s]
# Running evaluation: 7it [00:00, 103.63it/s]
# Running evaluation: 7it [00:00, 103.52it/s]
# Running evaluation: 7it [00:00, 104.35it/s]
# Running evaluation: 7it [00:00, 103.26it/s]
# Running evaluation: 7it [00:00, 103.20it/s]
# Running evaluation: 7it [00:00, 103.94it/s]
# Running evaluation: 7it [00:00, 103.05it/s]
# Running evaluation: 7it [00:00, 103.78it/s]
# Running evaluation: 7it [00:00, 103.76it/s]
# Running evaluation: 7it [00:00, 103.80it/s]
# Running evaluation: 7it [00:00, 101.56it/s]
# Running evaluation: 7it [00:00, 104.27it/s]
# Running evaluation: 7it [00:00, 103.71it/s]
# Running evaluation: 7it [00:00, 103.47it/s]
# Running evaluation: 7it [00:00, 104.10it/s]
# Running evaluation: 7it [00:00, 103.81it/s]
# Running evaluation: 7it [00:00, 82.21it/s]

# %% [markdown]
# ### Metrics

# %%
print("CRPS: {}".format(agg_metric['mean_wQuantileLoss']))
print("ND: {}".format(agg_metric['ND']))
print("NRMSE: {}".format(agg_metric['NRMSE']))
print("MSE: {}".format(agg_metric['MSE']))
# Out:
# CRPS: 0.5241581078742797
# ND: 0.5241581065413338
# NRMSE: 1.1173027805457048
# MSE: 1184.1849753244244

# %%
print("CRPS-Sum: {}".format(agg_metric['m_sum_mean_wQuantileLoss']))
print("ND-Sum: {}".format(agg_metric['m_sum_ND']))
print("NRMSE-Sum: {}".format(agg_metric['m_sum_NRMSE']))
print("MSE-Sum: {}".format(agg_metric['m_sum_MSE']))
# Out:
# CRPS-Sum: 0.45755129782675713
# ND-Sum: 0.45755131734895343
# NRMSE-Sum: 0.8650534869135346
# MSE-Sum: 13323087.041666668

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
